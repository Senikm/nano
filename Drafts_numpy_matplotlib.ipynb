# %%
import numpy as np

# %%
arr = np.random.randn(2, 2)
arr.shape
# Out:
# (2, 2)

# %%
arr
# Out:
# array([[-0.38812013,  1.7596905 ],
#        [ 0.02266965, -0.49692861]])

# %%
arr = np.pad(arr, ((1,1), (1,1)))

# %%
arr
# Out:
# array([[ 0.        ,  0.        ,  0.        ,  0.        ],
#        [ 0.        , -0.38812013,  1.7596905 ,  0.        ],
#        [ 0.        ,  0.02266965, -0.49692861,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.        ]])

# %%
from matplotlib import pyplot as plt
import matplotlib.image as img

# %%
im =  img.imread('sen.jpg')
#print(im)
im.shape
# Out:
# (1365, 1365, 3)

# %%
im = im [:, :, 0]
plt.imshow(im, cmap = "hot")
plt.colorbar()

# %%
plt.hist(im.ravel(), bins = 256)
# Out:
# (array([5.9500e+02, 2.2100e+02, 2.2100e+02, 2.7200e+02, 3.2200e+02,
#         3.5600e+02, 4.0200e+02, 5.0300e+02, 5.2700e+02, 6.2000e+02,
#         7.1300e+02, 7.7000e+02, 9.1200e+02, 9.6900e+02, 1.1380e+03,
#         1.1420e+03, 1.1970e+03, 1.2330e+03, 1.2990e+03, 1.3560e+03,
#         1.3530e+03, 1.3370e+03, 1.3100e+03, 1.3630e+03, 1.3480e+03,
#         1.2620e+03, 1.2490e+03, 1.3180e+03, 1.3060e+03, 1.2700e+03,
#         1.2970e+03, 1.2030e+03, 1.2020e+03, 1.1750e+03, 1.1950e+03,
#         1.0710e+03, 1.0770e+03, 1.0980e+03, 9.8400e+02, 9.5500e+02,
#         9.6100e+02, 8.4900e+02, 8.8600e+02, 8.2700e+02, 7.5500e+02,
#         7.5500e+02, 7.8500e+02, 7.5800e+02, 7.0000e+02, 7.2200e+02,
#         7.9500e+02, 7.8500e+02, 8.0500e+02, 8.2800e+02, 8.0400e+02,
#         8.7100e+02, 8.7000e+02, 8.7400e+02, 8.9500e+02, 1.0160e+03,
#         9.5500e+02, 1.0310e+03, 1.0500e+03, 1.1410e+03, 1.1640e+03,
#         1.0980e+03, 1.2790e+03, 1.2530e+03, 1.3360e+03, 1.3550e+03,
# ...
